# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def load_data(file_name):
    csv_folder = "csvs"
    file_path = f"{csv_folder}/{file_name}.csv"
    data = pd.read_csv(file_path)
    return data

# %%
def plot_data(data: pd.DataFrame, columns: list):
    for column in columns:
        plt.plot(data[column], label=column)
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.title('Data Plot')
    plt.legend()
    plt.show()

# %%
data = load_data('bts3v2_palm_down')
data
# Out:
#         object  slipped  ff_biotac_1  ff_biotac_2  ff_biotac_3  ff_biotac_4  \
# 0     pringles        0         2795         3097         3964         3197
# 1     pringles        0         2776         3075         3960         3115
# 2     pringles        0         2814         3106         3961         3176
# 3     pringles        0         2819         3114         3954         3195
# 4     pringles        0         2781         3094         3951         3208
# ...        ...      ...          ...          ...          ...          ...
# 1271  elephant        0         2903         3182         2886         3039
# 1272  elephant        1         2810         3100         2682         2917
# 1273  elephant        1         2799         3113         2673         2946
# 1274  elephant        1         2808         3077         2683         2942
# 1275  elephant        1         2802         3112         2671         2948
#
#       ff_biotac_5  ff_biotac_6  ff_biotac_7  ff_biotac_8  ...  th_biotac_15  \
# 0            2839         2635         2984         2589  ...          2886
# 1            2797         2457         2830         2307  ...          2874
# 2            2739         2692         2688         1857  ...          2872
# 3            2855         2613         2961         2531  ...          2893
# 4            2807         2726         3030         2660  ...          2897
# ...           ...          ...          ...          ...  ...           ...
# 1271         2641         2643         2904         2237  ...          2988
# 1272         2767         2313         2811         2545  ...          2972
# 1273         2836         2278         2851         2526  ...          2970
# 1274         2840         2289         2829         2497  ...          2980
# 1275         2853         2262         2839         2512  ...          2969
#
#       th_biotac_16  th_biotac_17  th_biotac_18  th_biotac_19  th_biotac_20  \
# 0             2579          2880          2795          2451          2166
# 1             2562          2878          2803          2469          2205
# 2             2551          2873          2770          2435          2182
# 3             2573          2892          2814          2460          2173
# 4             2538          2885          2820          2443          2168
# ...            ...           ...           ...           ...           ...
# 1271          2735          2992          2926          2575          2335
# 1272          2648          2953          2893          2531          2285
# 1273          2625          2944          2904          2530          2278
# 1274          2686          2972          2901          2543          2299
# 1275          2658          2963          2902          2536          2288
#
#       th_biotac_21  th_biotac_22  th_biotac_23  th_biotac_24
# 0             3008          2975          2986          2891
# 1             2985          2961          2980          2882
# 2             2990          2962          2980          2889
# 3             3010          2981          3000          2910
# 4             3012          2939          2999          2915
# ...            ...           ...           ...           ...
# 1271          3025          3024          3069          3001
# 1272          3072          3075          3076          2993
# 1273          3083          3081          3069          2999
# 1274          3078          3082          3074          2991
# 1275          3081          3064          3078          3003
#
# [1276 rows x 74 columns]

# %%
ff_biotac_1 = data['ff_biotac_1']
display(ff_biotac_1)
plot_data(data, ['ff_biotac_1'])
# Out:
# 0       2795
# 1       2776
# 2       2814
# 3       2819
# 4       2781
#         ...
# 1271    2903
# 1272    2810
# 1273    2799
# 1274    2808
# 1275    2802
# Name: ff_biotac_1, Length: 1276, dtype: int64
